# %% [markdown]
# [//]: <> (1.Introduction)
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Sleep_health_and_lifestyle_dataset</b></div>

# %% [markdown]
# The Sleep Health and Lifestyle Dataset comprises 400 rows and 13 columns, covering a wide range of variables related to sleep and daily habits. It includes details such as gender, age, occupation, sleep duration, quality of sleep, physical activity level, stress levels, BMI category, blood pressure, heart rate, daily steps, and the presence or absence of sleep disorders.
#
# Key Features of the Dataset:
#
# * Comprehensive Sleep Metrics: Explore sleep duration, quality, and factors influencing sleep patterns.
# * Lifestyle Factors: Analyze physical activity levels, stress levels, and BMI categories.
# * Cardiovascular Health: Examine blood pressure and heart rate measurements.
# * Sleep Disorder Analysis: Identify the occurrence of sleep disorders such as Insomnia and Sleep Apnea.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
data = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")

# %% [markdown]
# [//]: <> (1.Introduction)
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Domain Analysis of Dataset</b></div>

# %% [markdown]
# * Person ID: An identifier for each individual.
# * Gender: The gender of the person (Male/Female).
# * Age: The age of the person in years.
# * Occupation: The occupation or profession of the person.
# * Sleep Duration (hours): The number of hours the person sleeps per day.
# * Quality of Sleep (scale: 1-10): A subjective rating of the quality of sleep, ranging from 1 to 10.
# * Physical Activity Level (minutes/day): The number of minutes the person engages in physical activity daily.
# * Stress Level (scale: 1-10): A subjective rating of the stress level experienced by the person, ranging from 1 to 10.
# * BMI Category: The BMI category of the person (e.g., Underweight, Normal, Overweight).
# * Blood Pressure (systolic/diastolic): The blood pressure measurement of the person, indicated as systolic pressure over diastolic pressure.
# * Heart Rate (bpm): The resting heart rate of the person in beats per minute.
# * Daily Steps: The number of steps the person takes per day.
# * Sleep Disorder: The presence or absence of a sleep disorder in the person (None, Insomnia, Sleep Apnea).
#
# Details about Sleep Disorder Column:
# * None: The individual does not exhibit any specific sleep disorder.
# * Insomnia: The individual experiences difficulty falling asleep or staying asleep, leading to inadequate or poor-quality sleep.
# * Sleep Apnea: The individual suffers from pauses in breathing during sleep, resulting in disrupted sleep patterns and potential health risks.

# %%
# First five rows
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
# Last five rows
data.tail()
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# 373                       75             3   Overweight         140/95
#
#      Heart Rate  Daily Steps Sleep Disorder
# 369          68         7000    Sleep Apnea
# ...

# %%
# Shape of data
data.shape
# Out:
# (374, 13)

# %% [markdown]
# * Dataset contains 13 features with 374 observations.

# %%
# Columns in data
data.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
# Information of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
# Statistics of data
data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
# Statistics of data for categorical data
data.describe(include='O')
# Out:
#        Gender Occupation BMI Category Blood Pressure Sleep Disorder
# count     374        374          374            374            374
# unique      2         11            4             25              3
# top      Male      Nurse       Normal         130/85           None
# freq      189         73          195             99            219

# %%
data.nunique()
# Out:
# Person ID                  374
# Gender                       2
# Age                         31
# Occupation                  11
# Sleep Duration              27
# Quality of Sleep             6
# Physical Activity Level     16
# Stress Level                 6
# BMI Category                 4
# Blood Pressure              25
# Heart Rate                  19
# Daily Steps                 20
# Sleep Disorder               3
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# [//]: <> (1.Introduction)
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Data Exploratory Analysis</b></div>

# %%
# Univariate Analysis
categorical_data=data[['Gender','Occupation','BMI Category','Blood Pressure','Sleep Disorder']]
plt.figure(figsize=(20,20))
plotnumber=1
for column in categorical_data:
    if plotnumber<=6:
        plt.subplot(3,3,plotnumber)
        sns.countplot(x=data[column],hue='Quality of Sleep',data=data)
        plt.xticks(rotation=90)
    plotnumber+=1
plt.show()

# %%
numerical_data=data[['Age','Sleep Duration','Quality of Sleep', 'Physical Activity Level',
                     'Stress Level','Heart Rate', 'Daily Steps']]
plt.figure(figsize=(20,20))
plotnumber=1
for column in numerical_data:
    if plotnumber<=8:
        plt.subplot(3,3,plotnumber)
        sns.countplot(x=data[column],hue='Quality of Sleep',data=data)
        plt.xticks(rotation=90)
    plotnumber+=1
plt.show()

# %%
# Bivariate Abalysis
categorical_data=data[['Gender','Occupation','BMI Category','Blood Pressure','Sleep Disorder']]
plt.figure(figsize=(20,20))
plotnumber=1
for column in categorical_data:
    if plotnumber<=6:
        plt.subplot(3,3,plotnumber)
        sns.barplot(x=data[column],y='Quality of Sleep',data=data)
        plt.xticks(rotation=90)
    plotnumber+=1
plt.show()

# %%
numerical_data=data[['Age','Sleep Duration','Quality of Sleep', 'Physical Activity Level',
                     'Stress Level','Heart Rate', 'Daily Steps']]
plt.figure(figsize=(20,20))
plotnumber=1
for column in numerical_data:
    if plotnumber<=8:
        plt.subplot(3,3,plotnumber)
        sns.barplot(x=data[column],y='Quality of Sleep',data=data)
        plt.xticks(rotation=90)
    plotnumber+=1
plt.show()

# %%
# Multivariate Analysis
sns.pairplot(data)

# %% [markdown]
# [//]: <> (1.Introduction)
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Data Preprocessing </b></div>

# %%
# Check missing values in data
data.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %% [markdown]
# * No missing values present.

# %%
# Counts of gender
data.Gender.value_counts()
# Out:
# Male      189
# Female    185
# Name: Gender, dtype: int64

# %%
data.Gender=data.Gender.map({'Female':1,'Male':0})

# %%
data.Gender.value_counts()
# Out:
# 0    189
# 1    185
# Name: Gender, dtype: int64

# %%
data.Occupation.value_counts()
# Out:
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: Occupation, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
data.Occupation = lb.fit_transform(data.Occupation)

# %%
data['BMI Category'].value_counts()
# Out:
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: BMI Category, dtype: int64

# %%
data['BMI Category'] = lb.fit_transform(data['BMI Category'])

# %%
data['Sleep Disorder'].value_counts()
# Out:
# None           219
# Sleep Apnea     78
# Insomnia        77
# Name: Sleep Disorder, dtype: int64

# %%
data['Sleep Disorder'] = lb.fit_transform(data['Sleep Disorder'])

# %%
data['Blood Pressure'].unique()
# Out:
# array(['126/83', '125/80', '140/90', '120/80', '132/87', '130/86',
#        '117/76', '118/76', '128/85', '131/86', '128/84', '115/75',
#        '135/88', '129/84', '130/85', '115/78', '119/77', '121/79',
#        '125/82', '135/90', '122/80', '142/92', '140/95', '139/91',
#        '118/75'], dtype=object)

# %%
data['Blood Pressure']= data['Blood Pressure'].replace('/',' ',regex=True)

# %%
print(data['Blood Pressure'])
# Out:
# 0      126 83
# 1      125 80
# 2      125 80
# 3      140 90
# 4      140 90
#         ...
# 369    140 95
# 370    140 95
# 371    140 95
# 372    140 95
# 373    140 95
# Name: Blood Pressure, Length: 374, dtype: object

# %%
data['Blood Pressure']=pd.to_numeric(data['Blood Pressure'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    int64
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    int32
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    int32
#  9   Blood Pressure           0 non-null      float64
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    int32
# dtypes: float64(2), int32(3), int64(8)
# memory usage: 33.7 KB

# %% [markdown]
# ### Outlier Handling

# %%
plt.figure(figsize=(20,15))
plotno=1
for column in data:
    if plotno<=9:
        plt.subplot(3,3,plotno)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=20)
        plotno+=1
plt.tight_layout()

# %% [markdown]
# * No outliers present in data.

# %% [markdown]
# ### Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
numerical_data=data[['Age','Sleep Duration','Quality of Sleep', 'Physical Activity Level',
                     'Stress Level','Heart Rate', 'Daily Steps']]

# %%
numerical_data.head()
# Out:
#    Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0   27             6.1                 6                       42
# 1   28             6.2                 6                       60
# 2   28             6.2                 6                       60
# 3   28             5.9                 4                       30
# 4   28             5.9                 4                       30
#
#    Stress Level  Heart Rate  Daily Steps
# 0             6          77         4200
# 1             8          75        10000
# 2             8          75        10000
# 3             8          85         3000
# 4             8          85         3000

# %% [markdown]
# [//]: <> (1.Introduction)
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Feature Selection </b></div>

# %%
data.drop(['Person ID','Blood Pressure'],axis=1,inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(),annot=True,annot_kws={'size':15})
# Out:
# <AxesSubplot:>

# %% [markdown]
# [//]: <> (1.Introduction)
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Model Creation </b></div>

# %%
# Defining dependent & independent variables
x = data.drop('Quality of Sleep',axis=1)
y = data['Quality of Sleep']

# %%
# Creating training & testing data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (299, 10)
# x_test shape: (75, 10)
# y_train shape: (299,)
# y_test shape: (75,)

# %% [markdown]
# [//]: <> (1.Introduction)
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Building Model </b></div>

# %%
from sklearn.metrics import classification_report,accuracy_score

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_dt_predict = dt.predict(x_test)

# %%
print("Accuracy Score Decision Tree :",accuracy_score(y_test,y_dt_predict))
# Out:
# Accuracy Score Decision Tree : 1.0

# %%
print(classification_report(y_test,y_dt_predict))
# Out:
#               precision    recall  f1-score   support
#
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00        26
#            7       1.00      1.00      1.00        16
#            8       1.00      1.00      1.00        18
#            9       1.00      1.00      1.00        12
#
#     accuracy                           1.00        75
#    macro avg       1.00      1.00      1.00        75
# weighted avg       1.00      1.00      1.00        75

# %% [markdown]
# ### Logestic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_lr_predict=lr.predict(x_test)

# %%
print("Accuracy Score Linear Regression:",accuracy_score(y_test,y_lr_predict))
# Out:
# Accuracy Score Linear Regression: 0.5733333333333334

# %%
print(classification_report(y_test,y_lr_predict))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         2
#            5       0.20      1.00      0.33         1
#            6       0.61      0.77      0.68        26
#            7       0.00      0.00      0.00        16
#            8       0.43      0.56      0.49        18
#            9       1.00      1.00      1.00        12
#
#     accuracy                           0.57        75
#    macro avg       0.37      0.55      0.42        75
# weighted avg       0.48      0.57      0.52        75

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_rf_predict=rf.predict(x_test)

# %%
print("Accuracy Score Random Forest:",accuracy_score(y_test,y_rf_predict))
# Out:
# Accuracy Score Random Forest: 0.9733333333333334

# %%
print(classification_report(y_test,y_rf_predict))
# Out:
#               precision    recall  f1-score   support
#
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00        26
#            7       1.00      0.88      0.93        16
#            8       0.90      1.00      0.95        18
#            9       1.00      1.00      1.00        12
#
#     accuracy                           0.97        75
#    macro avg       0.98      0.98      0.98        75
# weighted avg       0.98      0.97      0.97        75

# %% [markdown]
# ### Bagging

# %%
from sklearn.ensemble import BaggingClassifier
bc=BaggingClassifier()
bc.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
y_bc_predict=bc.predict(x_test)

# %%
print("Accuracy Score Bagging:",accuracy_score(y_test,y_bc_predict))
# Out:
# Accuracy Score Bagging: 0.9733333333333334

# %%
print(classification_report(y_test,y_bc_predict))
# Out:
#               precision    recall  f1-score   support
#
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00        26
#            7       1.00      0.88      0.93        16
#            8       0.90      1.00      0.95        18
#            9       1.00      1.00      1.00        12
#
#     accuracy                           0.97        75
#    macro avg       0.98      0.98      0.98        75
# weighted avg       0.98      0.97      0.97        75

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_knn_predict=knn.predict(x_test)

# %%
print("Accuracy Score Kneighbor:",accuracy_score(y_test,y_knn_predict))
# Out:
# Accuracy Score Kneighbor: 0.96

# %%
print(classification_report(y_test,y_knn_predict))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         2
#            5       0.50      1.00      0.67         1
#            6       1.00      0.96      0.98        26
#            7       0.89      1.00      0.94        16
#            8       1.00      1.00      1.00        18
#            9       1.00      1.00      1.00        12
#
#     accuracy                           0.96        75
#    macro avg       0.73      0.83      0.76        75
# weighted avg       0.94      0.96      0.95        75

# %% [markdown]
# ### Support Vector Machine

# %%
from sklearn.svm import SVC
svc =SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_svc_predict=svc.predict(x_test)

# %%
print("Accuracy Score SVC:",accuracy_score(y_test,y_svc_predict))
# Out:
# Accuracy Score SVC: 0.37333333333333335

# %%
print(classification_report(y_test,y_svc_predict))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         2
#            5       0.00      0.00      0.00         1
#            6       1.00      0.19      0.32        26
#            7       0.00      0.00      0.00        16
#            8       0.53      0.94      0.68        18
#            9       0.16      0.50      0.24        12
#
#     accuracy                           0.37        75
#    macro avg       0.28      0.27      0.21        75
# weighted avg       0.50      0.37      0.31        75

# %% [markdown]
# [//]: <> (1.Introduction)
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b> Model Evaluation </b></div>

# %%
data = [{'Model': 'Decision Tree', 'Accuracy Score': accuracy_score(y_test,y_dt_predict)},
         {'Model': 'Logestic Regression Model', 'Accuracy Score': accuracy_score(y_test,y_lr_predict)},
         {'Model': 'Random Forest', 'Accuracy Score': accuracy_score(y_test,y_rf_predict)},
         {'Model': 'Bagging', 'Accuracy Score': accuracy_score(y_test,y_bc_predict)},
         {'Model': 'KNN', 'Accuracy Score':accuracy_score(y_test,y_knn_predict)},
       {'Model': 'SVC','Accuracy Score':accuracy_score(y_test,y_svc_predict)}]
  
df = pd.DataFrame.from_dict(data)
  
df
# Out:
#                        Model  Accuracy Score
# 0              Decision Tree        1.000000
# 1  Logestic Regression Model        0.573333
# 2              Random Forest        0.973333
# 3                    Bagging        0.973333
# 4                        KNN        0.960000
# 5                        SVC        0.373333

# %% [markdown]
# [//]: <> (1.Introduction)
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:35px;font-family:Georgia;text-align:left;display:fill;border-radius:5px;background-color:#254E58;overflow:hidden"><b>Conclusion </b></div>

# %% [markdown]
# The data shows that there is a clear correlation between sleep duration and quality. People who get enough sleep tend to have better sleep quality than those who do not. There are a number of factors that can affect sleep quality, including stress level, physical activity, and occupation. The best way to improve sleep quality is to make lifestyle changes that promote relaxation and reduce stress.
